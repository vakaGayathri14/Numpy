# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6])
arr2 = np.array([4,5,6,7,8,9])

# %%
arr1-arr2
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %%
arr1 * arr2 # vector multiplication (vector * vector)
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %%
arr1*2 # scalar multiplication (vector * scalar)
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
arr2>3 # in arr2 wherever it is greater than 3 it will give you false here all values are greater than 3 so all are true
# Out:
# array([ True,  True,  True,  True,  True,  True])

# %%
arr2>5
# Out:
# array([False, False,  True,  True,  True,  True])

# %%
arr3 = np.arange(6).reshape(2,3)
arr4 = np.arange(6,12).reshape(3,2)

# %%
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr3.dot(arr4)
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1.dot(arr2)
# Out:
# np.int64(154)

# %%
arr1.dot(arr3) # it will throw an error because it doesn't match
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 arr1.dot(arr3)
#
# ValueError: shapes (6,) and (2,3) not aligned: 6 (dim 0) != 2 (dim 0)

# %%
arr4.max() # it will give you max number
# Out:
# np.int64(11)

# %%
arr4.min()
# Out:
# np.int64(6)

# %%
arr4.min(axis=0) #here axis is 0 means i want o/p in column wise how many column 2, so o/p is 6,7 # here I am getting minimum of each column
# Out:
# array([6, 7])

# %%
# if i want row wise then, here I am getting minimum of each row 
arr4.min(axis=1)
# Out:
# array([ 6,  8, 10])

# %%
arr4.sum() # calculae the sum
# Out:
# np.int64(51)

# %%
arr4.sum(axis=0) # column wise sum
# Out:
# array([24, 27])

# %%
arr4.mean() # mean of the dataset
# Out:
# np.float64(8.5)

# %%
arr4.std() # standard deviation for the entire data
# Out:
# np.float64(1.707825127659933)

# %%
arr4.sin()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 arr4.sin()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sin'

# %%
np.sin(arr4)
# Out:
# array([[-0.2794155 ,  0.6569866 ],
#        [ 0.98935825,  0.41211849],
#        [-0.54402111, -0.99999021]])

# %%
np.median(arr4)
# Out:
# np.float64(8.5)

# %%
np.exp(arr4) # exponent
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])
